# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
state = np.load("../data/device_1.npz")
print(state.files)
events = state["event_counts"]

print(events.sum)
plt.imshow(events)
# Out:
# ['ID', 'acceptor_coordinates', 'donor_coordinates', 'electrode_coordinates', 'event_counts', 'device_time']
# <built-in method sum of numpy.ndarray object at 0x76bd72b7d3b0>

# %%
batch = np.load("../data/batch_testing.npz")

print(batch.files)

inputs = batch["inputs"]
outputs = batch["outputs"]

print(inputs.shape)
print(outputs.shape)

plt.scatter(inputs[:,1], outputs)
# Out:
# ['ID', 'inputs', 'outputs']
# (100, 8)
# (100,)
