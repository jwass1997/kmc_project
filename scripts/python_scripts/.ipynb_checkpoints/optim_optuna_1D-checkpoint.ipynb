# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
from sm import NeuralNet
from tune_sm import find_control_voltages_1D
import optuna

device = 'cuda'
print(device)

def target_function(t: torch.Tensor):
    
    N = t.shape[0]
    m = nn.ReLU()
    
    return t#m(t)#0.1*t**2 + torch.sin(3*t)

def normalize_over_range(x):
    z = (x - x.mean()) / (x.std() + 1e-8) 
    return z

def forward_whole_range(model, param_list, input_idx, v_min, v_max, N):

    in_range = torch.linspace(v_min, v_max, N).unsqueeze(1)

    c_volt = torch.tensor(param_list, dtype=torch.float32).expand(N, -1)
    c_volt_l = c_volt[:, :input_idx]
    c_volt_r = c_volt[:, input_idx:]

    input_tensor = torch.cat([c_volt_l, in_range, c_volt_r], dim=1)

    model.eval()
    with torch.no_grad():
        y_out = model(input_tensor).detach().cpu().numpy()

    return y_out

state_dict = torch.load("/gpfs/bwfor/work/ws/hd_gy283-my_data/models/sm_vMB_n_a=200.pth", map_location="cpu", weights_only=False)
print(state_dict['args'])

x_mean = state_dict['args']['x_mean']
x_std = state_dict['args']['x_std']
y_mean = state_dict['args']['y_mean']
y_std = state_dict['args']['y_std']
layer_dims = state_dict['args']['layer_dims']

model = NeuralNet(layer_dims, x_mean, x_std, y_mean, y_std)

model.load_state_dict(state_dict['model_state_dict'])
model.eval()

N = 100
in_range = torch.linspace(-1.5, 1.5, N).unsqueeze(1)
target = target_function(in_range)
# Out:
# 4.4.0
# cuda
# cuda
# {'data_dir': PosixPath('/gpfs/bwfor/work/ws/hd_gy283-my_data/data_vMB_own_pde_solver'), 'num_batches': 180, 'batch_size': 512, 'x_mean': array([-8.01042443e-05, -4.84397956e-05,  1.27591542e-04, -1.36573186e-03,
#         1.29713429e-03,  9.82766649e-04, -6.81038087e-04]), 'x_std': array([0.86585553, 0.86589274, 0.86606062, 0.865617  , 0.86568139,
#        0.86553458, 0.86612566]), 'y_mean': np.float64(-0.03779365664983197), 'y_std': np.float64(0.14455336756115278), 'layer_dims': [7, 128, 128, 128, 1], 'num_epochs': 500, 'lr': 0.001, 'save_name': PosixPath('/home/hd/hd_hd/hd_gy283/kmc_project/models/sm_vMB_n_a=200')}

# %%
study = find_control_voltages_1D(
    model=model, 
    target=target, 
    N=N, 
    c_volt_min=-1.5, 
    c_volt_max=1.5, 
    in_volt_min=-1.5, 
    in_volt_max=1.5, 
    input_idx=0, 
    n_startup_trials=500, 
    n_trials=1000, 
    PRINT_EVERY=100
)

print("Best value:", study.best_value)
print("Best params:", study.best_params)  

best_vals = []

for v in study.best_params.items():
    best_vals.append(v[1])
print(best_vals)
# Out:
# 0] Finished with score:  0.135173
# 100] Finished with score:  0.265448
# 200] Finished with score:  0.161367
# 300] Finished with score:  0.144044
# 400] Finished with score:  0.280752
# 500] Finished with score:  0.105756
# 600] Finished with score:  0.032827
# 700] Finished with score:  0.038208
# 800] Finished with score:  0.034280
# 900] Finished with score:  0.033142
# Best value: 0.03164363044500351
# Best params: {'x_0': -1.4993585571687573, 'x_1': -1.4940815046433964, 'x_2': -0.8351970808666014, 'x_3': 0.9108973804341518, 'x_4': 1.2629079376914545, 'x_5': 1.4985793189762304}
# [-1.4993585571687573, -1.4940815046433964, -0.8351970808666014, 0.9108973804341518, 1.2629079376914545, 1.4985793189762304]

# %%
y_out = forward_whole_range(model, best_vals, 0, -1.5, 1.5, N) 

y_norm = normalize_over_range(y_out)
t_norm = normalize_over_range(target)

plt.plot(in_range, y_norm)
plt.plot(in_range, t_norm)

# %%
num_runs = 200
opt_param_list = []
for i in range(num_runs):
    study = find_control_voltages_1D(
        model=model, 
        target=target, 
        N=N, 
        c_volt_min=-1.5, 
        c_volt_max=1.5, 
        in_volt_min=-1.5, 
        in_volt_max=1.5, 
        input_idx=0, 
        n_startup_trials=100, 
        n_trials=1000, 
        PRINT_EVERY=100000
    )
    if i % 10 == 0:
        print("Best value:", study.best_value)
        print("Best params:", study.best_params)  
    
    best_vals = []
    
    for v in study.best_params.items():
        best_vals.append(v[1])
    opt_param_list.append(best_vals)
# Out:
# 0] Finished with score:  0.380789
# Best value: 0.018745626360177993
# Best params: {'x_0': -0.4678383546181246, 'x_1': -0.9406975757714735, 'x_2': -1.4944357616852653, 'x_3': -1.4990110670469776, 'x_4': -1.3937316450259496, 'x_5': -0.7557526841126032}
# 0
# 0] Finished with score:  0.376528
# 1
# 0] Finished with score:  0.207961
# 2
# 0] Finished with score:  0.901804
# 3
# 0] Finished with score:  0.421638
# 4
# 0] Finished with score:  1.015560
# 5
# 0] Finished with score:  0.280775
# 6
# 0] Finished with score:  0.105068
# 7
# 0] Finished with score:  1.273438
# 8
# 0] Finished with score:  0.383498
# 9
# 0] Finished with score:  0.231158
# Best value: 0.009309311382472514
# Best params: {'x_0': -1.4974779342987359, 'x_1': -1.4433435593086807, 'x_2': -1.452484290330141, 'x_3': -0.6900039222066094, 'x_4': 1.1935158178548062, 'x_5': -0.6690948465287797}
# 10
# 0] Finished with score:  0.353437
# 11
# 0] Finished with score:  0.407407
# 12
# 0] Finished with score:  0.109300
# 13
# 0] Finished with score:  0.188820
# 14
# 0] Finished with score:  0.301573
# [W 2025-10-13 10:17:54,594] Trial 485 failed with parameters: {'x_0': -1.4995865634829268, 'x_1': -1.2811179833664113, 'x_2': -1.1354231862764819, 'x_3': 0.25652157782221013} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/home/hd/hd_hd/hd_gy283/.conda/envs/py311/lib/python3.11/site-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/home/hd/hd_hd/hd_gy283/kmc_project/scripts/python_scripts/tune_sm.py", line 34, in objective
#     cv_list = [trial.suggest_float(f"x_{i}", c_volt_min, c_volt_max) for i in range(6)]
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hd/hd_hd/hd_gy283/kmc_project/scripts/python_scripts/tune_sm.py", line 34, in <listcomp>
#     cv_list = [trial.suggest_float(f"x_{i}", c_volt_min, c_volt_max) for i in range(6)]
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hd/hd_hd/hd_gy283/.conda/envs/py311/lib/python3.11/site-packages/optuna/trial/_trial.py", line 161, in suggest_float
#     suggested_value = self._suggest(name, distribution)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hd/hd_hd/hd_gy283/.conda/envs/py311/lib/python3.11/site-packages/optuna/trial/_trial.py", line 635, in _suggest
#     param_value = self.study.sampler.sample_independent(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hd/hd_hd/hd_gy283/.conda/envs/py311/lib/python3.11/site-packages/optuna/samplers/_tpe/sampler.py", line 458, in sample_independent
#     return self._sample(study, trial, {param_name: param_distribution})[param_name]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hd/hd_hd/hd_gy283/.conda/envs/py311/lib/python3.11/site-packages/optuna/samplers/_tpe/sampler.py", line 499, in _sample
#     acq_func_vals = self._compute_acquisition_func(samples_below, mpe_below, mpe_above)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hd/hd_hd/hd_gy283/.conda/envs/py311/lib/python3.11/site-packages/optuna/samplers/_tpe/sampler.py", line 544, in _compute_acquisition_func
#     log_likelihoods_below = mpe_below.log_pdf(samples)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hd/hd_hd/hd_gy283/.conda/envs/py311/lib/python3.11/site-packages/optuna/samplers/_tpe/parzen_estimator.py", line 82, in log_pdf
#     return self._mixture_distribution.log_pdf(transformed_samples)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hd/hd_hd/hd_gy283/.conda/envs/py311/lib/python3.11/site-packages/optuna/samplers/_tpe/probability_distributions.py", line 93, in log_pdf
#     log_pdfs[:, :, i] = _truncnorm.logpdf(
#                         ^^^^^^^^^^^^^^^^^^
#   File "/home/hd/hd_hd/hd_gy283/.conda/envs/py311/lib/python3.11/site-packages/optuna/samplers/_tpe/_truncnorm.py", line 231, in logpdf
#     out = _norm_logpdf(x) - _log_gauss_mass(a, b) - np.log(scale)
#                             ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hd/hd_hd/hd_gy283/.conda/envs/py311/lib/python3.11/site-packages/optuna/samplers/_tpe/_truncnorm.py", line 147, in _log_gauss_mass
#     out[case_central] = mass_case_central(a[case_central], b[case_central])
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hd/hd_hd/hd_gy283/.conda/envs/py311/lib/python3.11/site-packages/optuna/samplers/_tpe/_truncnorm.py", line 138, in mass_case_central
#     return np.log1p(-_ndtr(a) - _ndtr(-b))
#                      ^^^^^^^^
#   File "/home/hd/hd_hd/hd_gy283/.conda/envs/py311/lib/python3.11/site-packages/optuna/samplers/_tpe/_truncnorm.py", line 74, in _ndtr
#     return 0.5 + 0.5 * erf(a / 2**0.5)
#                        ^^^^^^^^^^^^^^^
#   File "/home/hd/hd_hd/hd_gy283/.conda/envs/py311/lib/python3.11/site-packages/optuna/samplers/_tpe/_erf.py", line 175, in erf
#     out[case_small1] = calc_case_small1(x[case_small1])
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hd/hd_hd/hd_gy283/.conda/envs/py311/lib/python3.11/site-packages/optuna/samplers/_tpe/_erf.py", line 126, in calc_case_small1
#     r = pp(z)
#         ^^^^^
#   File "/home/hd/hd_hd/hd_gy283/.conda/envs/py311/lib/python3.11/site-packages/numpy/polynomial/_polybase.py", line 510, in __call__
#     def __call__(self, arg):
#
# KeyboardInterrupt
# [W 2025-10-13 10:17:54,708] Trial 485 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       2 opt_param_list = []
#       3 for i in range(num_runs):
# ----> 4     study = find_control_voltages_1D(
#       5         model=model,
#       6         target=target,
#       7         N=N,
#       8         c_volt_min=-1.5,
#       9         c_volt_max=1.5,
#      10         in_volt_min=-1.5,
#      11         in_volt_max=1.5,
#      12         input_idx=0,
#      13         n_startup_trials=100,
#      14         n_trials=1000,
#      15         PRINT_EVERY=100000
#      16     )
#      17     if i % 10 == 0:
#      18         print("Best value:", study.best_value)
#
# File ~/kmc_project/scripts/python_scripts/tune_sm.py:55, in find_control_voltages_1D(model, target, N, input_idx, c_volt_min, c_volt_max, in_volt_min, in_volt_max, n_startup_trials, n_trials, PRINT_EVERY)
#      53 #sampler = optuna.samplers.RandomSampler()
#      54 study = optuna.create_study(direction="minimize", sampler=sampler)
# ---> 55 study.optimize(objective, n_trials=n_trials)
#      57 return study
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/optuna/study/study.py:489, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     387 def optimize(
#     388     self,
#     389     func: ObjectiveFuncType,
#    (...)    396     show_progress_bar: bool = False,
#     397 ) -> None:
#     398     """Optimize an objective function.
#     399
#     400     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    487             If nested invocation of this method occurs.
#     488     """
# --> 489     _optimize(
#     490         study=self,
#     491         func=func,
#     492         n_trials=n_trials,
#     493         timeout=timeout,
#     494         n_jobs=n_jobs,
#     495         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     496         callbacks=callbacks,
#     497         gc_after_trial=gc_after_trial,
#     498         show_progress_bar=show_progress_bar,
#     499     )
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/optuna/study/_optimize.py:64, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      62 try:
#      63     if n_jobs == 1:
# ---> 64         _optimize_sequential(
#      65             study,
#      66             func,
#      67             n_trials,
#      68             timeout,
#      69             catch,
#      70             callbacks,
#      71             gc_after_trial,
#      72             reseed_sampler_rng=False,
#      73             time_start=None,
#      74             progress_bar=progress_bar,
#      75         )
#      76     else:
#      77         if n_jobs == -1:
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/optuna/study/_optimize.py:161, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     158         break
#     160 try:
# --> 161     frozen_trial = _run_trial(study, func, catch)
#     162 finally:
#     163     # The following line mitigates memory problems that can be occurred in some
#     164     # environments (e.g., services that use computing containers such as GitHub Actions).
#     165     # Please refer to the following PR for further details:
#     166     # https://github.com/optuna/optuna/pull/325.
#     167     if gc_after_trial:
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/optuna/study/_optimize.py:253, in _run_trial(study, func, catch)
#     246         assert False, "Should not reach."
#     248 if (
#     249     frozen_trial.state == TrialState.FAIL
#     250     and func_err is not None
#     251     and not isinstance(func_err, catch)
#     252 ):
# --> 253     raise func_err
#     254 return frozen_trial
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/optuna/study/_optimize.py:201, in _run_trial(study, func, catch)
#     199 with get_heartbeat_thread(trial._trial_id, study._storage):
#     200     try:
# --> 201         value_or_values = func(trial)
#     202     except exceptions.TrialPruned as e:
#     203         # TODO(mamu): Handle multi-objective cases.
#     204         state = TrialState.PRUNED
#
# File ~/kmc_project/scripts/python_scripts/tune_sm.py:34, in find_control_voltages_1D.<locals>.objective(trial)
#      32 def objective(trial):
# ---> 34     cv_list = [trial.suggest_float(f"x_{i}", c_volt_min, c_volt_max) for i in range(6)]
#      35     cv_tensor = torch.tensor(cv_list, dtype=torch.float32)
#      36     cv_input = cv_tensor.expand(N, -1)
#
# File ~/kmc_project/scripts/python_scripts/tune_sm.py:34, in <listcomp>(.0)
#      32 def objective(trial):
# ---> 34     cv_list = [trial.suggest_float(f"x_{i}", c_volt_min, c_volt_max) for i in range(6)]
#      35     cv_tensor = torch.tensor(cv_list, dtype=torch.float32)
#      36     cv_input = cv_tensor.expand(N, -1)
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/optuna/trial/_trial.py:161, in Trial.suggest_float(self, name, low, high, step, log)
#      85 """Suggest a value for the floating point parameter.
#      86
#      87 Example:
#    (...)    157     :ref:`configurations` tutorial describes more details and flexible usages.
#     158 """
#     160 distribution = FloatDistribution(low, high, log=log, step=step)
# --> 161 suggested_value = self._suggest(name, distribution)
#     162 self._check_distribution(name, distribution)
#     163 return suggested_value
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/optuna/trial/_trial.py:635, in Trial._suggest(self, name, distribution)
#     633 else:
#     634     study = pruners._filter_study(self.study, trial)
# --> 635     param_value = self.study.sampler.sample_independent(
#     636         study, trial, name, distribution
#     637     )
#     639 # `param_value` is validated here (invalid value like `np.nan` raises ValueError).
#     640 param_value_in_internal_repr = distribution.to_internal_repr(param_value)
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/optuna/samplers/_tpe/sampler.py:458, in TPESampler.sample_independent(self, study, trial, param_name, param_distribution)
#     448     if any(param_name in trial.params for trial in trials):
#     449         _logger.warning(
#     450             f"The parameter '{param_name}' in trial#{trial.number} is sampled "
#     451             "independently instead of being sampled by multivariate TPE sampler. "
#    (...)    455             "if this independent sampling is intended behavior."
#     456         )
# --> 458 return self._sample(study, trial, {param_name: param_distribution})[param_name]
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/optuna/samplers/_tpe/sampler.py:499, in TPESampler._sample(self, study, trial, search_space)
#     494 mpe_above = self._build_parzen_estimator(
#     495     study, search_space, above_trials, handle_below=False
#     496 )
#     498 samples_below = mpe_below.sample(self._rng.rng, self._n_ei_candidates)
# --> 499 acq_func_vals = self._compute_acquisition_func(samples_below, mpe_below, mpe_above)
#     500 ret = TPESampler._compare(samples_below, acq_func_vals)
#     502 for param_name, dist in search_space.items():
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/optuna/samplers/_tpe/sampler.py:544, in TPESampler._compute_acquisition_func(self, samples, mpe_below, mpe_above)
#     538 def _compute_acquisition_func(
#     539     self,
#     540     samples: dict[str, np.ndarray],
#     541     mpe_below: _ParzenEstimator,
#     542     mpe_above: _ParzenEstimator,
#     543 ) -> np.ndarray:
# --> 544     log_likelihoods_below = mpe_below.log_pdf(samples)
#     545     log_likelihoods_above = mpe_above.log_pdf(samples)
#     546     acq_func_vals = log_likelihoods_below - log_likelihoods_above
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/optuna/samplers/_tpe/parzen_estimator.py:82, in _ParzenEstimator.log_pdf(self, samples_dict)
#      80 def log_pdf(self, samples_dict: dict[str, np.ndarray]) -> np.ndarray:
#      81     transformed_samples = self._transform(samples_dict)
# ---> 82     return self._mixture_distribution.log_pdf(transformed_samples)
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/optuna/samplers/_tpe/probability_distributions.py:93, in _MixtureOfProductDistribution.log_pdf(self, x)
#      87     log_pdfs[:, :, i] = np.log(
#      88         np.take_along_axis(
#      89             d.weights[None, :, :], xi[:, None, None].astype(np.int64), axis=-1
#      90         )
#      91     )[:, :, 0]
#      92 elif isinstance(d, _BatchedTruncNormDistributions):
# ---> 93     log_pdfs[:, :, i] = _truncnorm.logpdf(
#      94         x=xi[:, None],
#      95         a=(d.low - d.mu[None, :]) / d.sigma[None, :],
#      96         b=(d.high - d.mu[None, :]) / d.sigma[None, :],
#      97         loc=d.mu[None, :],
#      98         scale=d.sigma[None, :],
#      99     )
#     100 elif isinstance(d, _BatchedDiscreteTruncNormDistributions):
#     101     lower_limit = d.low - d.step / 2
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/optuna/samplers/_tpe/_truncnorm.py:231, in logpdf(x, a, b, loc, scale)
#     227 x = (x - loc) / scale
#     229 x, a, b = np.atleast_1d(x, a, b)
# --> 231 out = _norm_logpdf(x) - _log_gauss_mass(a, b) - np.log(scale)
#     233 x, a, b = np.broadcast_arrays(x, a, b)
#     234 out[(x < a) | (b < x)] = -np.inf
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/optuna/samplers/_tpe/_truncnorm.py:147, in _log_gauss_mass(a, b)
#     145     out[case_right] = mass_case_right(a[case_right], b[case_right])
#     146 if a[case_central].size:
# --> 147     out[case_central] = mass_case_central(a[case_central], b[case_central])
#     148 return np.real(out)
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/optuna/samplers/_tpe/_truncnorm.py:138, in _log_gauss_mass.<locals>.mass_case_central(a, b)
#     127 def mass_case_central(a: np.ndarray, b: np.ndarray) -> np.ndarray:
#     128     # Previously, this was implemented as:
#     129     # left_mass = mass_case_left(a, 0)
#    (...)    136     # the result can't accurately be represented in logspace anyway
#     137     # because sc.log1p(x) ~ x for small x.
# --> 138     return np.log1p(-_ndtr(a) - _ndtr(-b))
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/optuna/samplers/_tpe/_truncnorm.py:74, in _ndtr(a)
#      72 def _ndtr(a: np.ndarray) -> np.ndarray:
#      73     # todo(amylase): implement erfc in _erf.py and use it for big |a| inputs.
# ---> 74     return 0.5 + 0.5 * erf(a / 2**0.5)
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/optuna/samplers/_tpe/_erf.py:175, in erf(x)
#     173     out[case_tiny] = calc_case_tiny(x[case_tiny])
#     174 if x[case_small1].size:
# --> 175     out[case_small1] = calc_case_small1(x[case_small1])
#     176 if x[case_small2].size:
#     177     out[case_small2] = calc_case_small2(x[case_small2])
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/optuna/samplers/_tpe/_erf.py:126, in erf.<locals>.calc_case_small1(x)
#     124 def calc_case_small1(x: np.ndarray) -> np.ndarray:
#     125     z = x * x
# --> 126     r = pp(z)
#     127     s = qq(z)
#     128     y = r / s
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/numpy/polynomial/_polybase.py:510, in ABCPolyBase.__call__(self, arg)
#     506     self.__dict__ = dict
#     508 # Call
# --> 510 def __call__(self, arg):
#     511     arg = pu.mapdomain(arg, self.domain, self.window)
#     512     return self._val(arg, self.coef)
#
# KeyboardInterrupt:

# %%
opt_param_arr = np.stack(opt_param_list)
np.save('opt_param_arr_relu_opt.npy', opt_param_arr)
d = 6
fig, ax = plt.subplots(ncols=d, figsize=(3*d, 3))

for a in ax:
    a.set_box_aspect(1)

for i in range(d):
    ax[i].hist(opt_param_arr[:, i], bins=15, alpha=.75)

# %% [markdown]
# ## 2.)  2D

# %%
xs, ys = np.meshgrid(np.linspace(-1.5, 1.5, N), np.linspace(-1.5, 1.5, N))

def target_2d(x, y):
    z = 1 / (1 + x - y)
