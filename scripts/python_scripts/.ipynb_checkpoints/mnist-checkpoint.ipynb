# %%
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
from sm import NeuralNet, LearnableActivationFunc

from sm import LearnableActivationFunc

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,)),
])

train_ds = datasets.MNIST(root='./data', train=True, download=False, transform=transform)
test_ds  = datasets.MNIST(root='./data', train=False, download=False, transform=transform)

train_loader = DataLoader(train_ds, batch_size=128, shuffle=True, num_workers=2)
test_loader  = DataLoader(test_ds, batch_size=256, shuffle=False, num_workers=2)
len(train_ds), len(test_ds)
# Out:
# (60000, 10000)

# %%
state_dict = torch.load("/gpfs/bwfor/work/ws/hd_gy283-my_data/models/sm_vMB_n_a=200.pth", weights_only=False, map_location='cpu')
print(state_dict['args'])
model = NeuralNet(
    state_dict['args']['layer_dims'],
    state_dict['args']['x_mean'],
    state_dict['args']['x_std'],
    state_dict['args']['y_mean'],
    state_dict['args']['y_std']
)
model.load_state_dict(state_dict['model_state_dict'])

class SmallCNN(nn.Module):
    def __init__(self, model):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 16, 3, padding=1)   # 28x28 -> 28x28
        self.pool  = nn.MaxPool2d(2, 2)                # 28x28 -> 14x14
        self.conv2 = nn.Conv2d(16, 32, 3, padding=1)   # 14x14 -> 14x14
        self.fc1   = nn.Linear(32 * 14 * 14, 64)
        self.fc2   = nn.Linear(64, 10)

        self.act1 = LearnableActivationFunc(model, 3, -1.5, 1.5, None, device=None)
        self.act2 = LearnableActivationFunc(model, 3, -1.5, 1.5, None, device=None)
        self.act3 = LearnableActivationFunc(model, 3, -1.5, 1.5, None, device=None)

    def forward(self, x):
        x = self.conv1(x)
        x = self.act1(x)
        x = self.conv2(x)
        x = self.act2(x)
        x = self.pool(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = self.act3(x)
        x = self.fc2(x)
        return x

net = SmallCNN(model).to(device)
sum(p.numel() for p in net.parameters())
# Out:
# {'data_dir': PosixPath('/gpfs/bwfor/work/ws/hd_gy283-my_data/data_vMB_own_pde_solver'), 'num_batches': 180, 'batch_size': 512, 'x_mean': array([-8.01042443e-05, -4.84397956e-05,  1.27591542e-04, -1.36573186e-03,
#         1.29713429e-03,  9.82766649e-04, -6.81038087e-04]), 'x_std': array([0.86585553, 0.86589274, 0.86606062, 0.865617  , 0.86568139,
#        0.86553458, 0.86612566]), 'y_mean': np.float64(-0.03779365664983197), 'y_std': np.float64(0.14455336756115278), 'layer_dims': [7, 128, 128, 128, 1], 'num_epochs': 500, 'lr': 0.001, 'save_name': PosixPath('/home/hd/hd_hd/hd_gy283/kmc_project/models/sm_vMB_n_a=200')}
# 509471

# %%
optimizer = torch.optim.Adam(net.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss()
EPOCHS = 10

for epoch in range(1, EPOCHS+1):
    net.train()
    running_loss, correct, total = 0.0, 0, 0
    for x, y in train_loader:
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad(set_to_none=True)
        out = net(x)
        loss = criterion(out, y)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * x.size(0)
        pred = out.argmax(1)
        correct += (pred == y).sum().item()
        total += y.size(0)

    train_loss = running_loss / total
    train_acc = correct / total
    print(f'Training | Epoch {epoch}/{EPOCHS} | Loss: {train_loss:.4f} | Acc: {100. * train_acc:.4f}')

    net.eval()
    with torch.no_grad():
        running_loss = 0.0
        correct = 0
        total = 0
        for x, y in test_loader:
            x, y = x.to(device), y.to(device)
            out = net(x)

            loss = criterion(out, y)
            running_loss += loss.item() * x.size(0)
            pred = out.argmax(1)
            correct += (pred == y).sum().item()
            total += y.size(0)
        print(f'Testing | Loss: {running_loss / total} | Acc: {100. * correct / total:.4f}')

torch.save(net.state_dict(), f'/gpfs/bwfor/work/ws/hd_gy283-my_data/models/mnist_net.pth')
# Out:
# Training | Epoch 1/10 | Loss: 2.3020 | Acc: 10.9083
# Testing | Loss: 2.3010079887390136 | Acc: 11.3500
# Training | Epoch 2/10 | Loss: 2.3013 | Acc: 11.2367
# Testing | Loss: 2.300995640563965 | Acc: 11.3500
# Training | Epoch 3/10 | Loss: 2.3013 | Acc: 11.2367
# Testing | Loss: 2.301004214477539 | Acc: 11.3500
# Training | Epoch 4/10 | Loss: 2.3013 | Acc: 11.2367
# Testing | Loss: 2.3010096755981446 | Acc: 11.3500
# Training | Epoch 5/10 | Loss: 2.3013 | Acc: 11.2367
# Testing | Loss: 2.3010395778656005 | Acc: 11.3500
# Training | Epoch 6/10 | Loss: 2.3013 | Acc: 11.2367
# Testing | Loss: 2.3010225978851317 | Acc: 11.3500
# Training | Epoch 7/10 | Loss: 2.3013 | Acc: 11.2367
# Testing | Loss: 2.301071203994751 | Acc: 11.3500
# Training | Epoch 8/10 | Loss: 2.3013 | Acc: 11.2367
# Testing | Loss: 2.3011440433502197 | Acc: 11.3500
# Training | Epoch 9/10 | Loss: 2.3013 | Acc: 11.2367
# Testing | Loss: 2.3010772888183593 | Acc: 11.3500
# ...
