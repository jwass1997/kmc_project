# %%
import numpy as np
import matplotlib.pyplot as plt


data_non_uniform = np.load(f"/gpfs/bwfor/work/ws/hd_gy283-my_data/example_curves/non_uniform_dist.npz")
data_vonMises_beta = np.load(f"/gpfs/bwfor/work/ws/hd_gy283-my_data/example_curves/vonMises_beta.npz")
data_vonMises_beta_0 = np.load(f"/gpfs/bwfor/work/ws/hd_gy283-my_data/example_curves/vonMises_beta_0.npz")
data_vonMises_beta_1 = np.load(f"/gpfs/bwfor/work/ws/hd_gy283-my_data/example_curves/vonMises_beta_1.npz")
data_vonMises_beta_2 = np.load(f"/gpfs/bwfor/work/ws/hd_gy283-my_data/example_curves/vonMises_beta_2.npz")
data_uniform_0 = np.load(f"/gpfs/bwfor/work/ws/hd_gy283-my_data/example_curves/uniform_0.npz")
data_uniform_1 = np.load(f"/gpfs/bwfor/work/ws/hd_gy283-my_data/example_curves/uniform_1.npz")
data_uniform_1_jiggled = np.load(f"/gpfs/bwfor/work/ws/hd_gy283-my_data/example_curves/uniform_1_jiggled.npz")

vs = np.linspace(-1.5, 1.5, data_non_uniform["current"].shape[0])
#plt.plot(vs, data_non_uniform["current"], label="non_uniform")
plt.plot(vs, data_vonMises_beta["current"], label="vonMises_beta")
#plt.plot(vs, data_vonMises_beta_0["current"], label="vonMises_beta_0")
plt.plot(vs, data_vonMises_beta_1["current"], label="vonMises_beta_1")
plt.plot(vs, data_vonMises_beta_2["current"], label="vonMises_beta_2")
#plt.plot(vs, data_uniform_0["current"], label="uniform_0")
#plt.plot(vs, data_uniform_1["current"], label="uniform_1")
#plt.plot(vs, data_uniform_1_jiggled["current"], label="uniform_1_jiggled")
plt.legend()

ax = plt.gca()
ax.grid(True)
ax.set_facecolor("lightgray")
ax.xaxis.set_tick_params(width=2.0)
ax.yaxis.set_tick_params(width=2.0)
ax.spines[['top', 'bottom', 'left', 'right']].set_linewidth(2.0)

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

class MakeDataset(Dataset):
    def __init__(self, x_data, labels=None):

        if isinstance(x_data, torch.Tensor):
            self.X = x_data.float()
        elif isinstance(x_data, np.ndarray):
            self.X = torch.from_numpy(x_data).float()
        else:
            raise TypeError(f"x_data must be a numpy array or torch.Tensor, got {type(x_data)}")

        if labels is not None:
            if isinstance(labels, torch.Tensor):
                y = labels.float()
            elif isinstance(labels, np.ndarray):
                y = torch.from_numpy(labels).float()
            else:
                raise TypeError(f"labels must be a numpy array or torch.Tensor, got {type(labels)}")

            if y.dim() == 1:
                y = y.unsqueeze(1)

            if y.size(0) != self.X.size(0):
                raise ValueError("inputs and labels must have the same length")

            self.y = y
        else:
            self.y = None

    def __len__(self):
        return self.X.size(0)

    def __getitem__(self, idx):
        x = self.X[idx]
        if self.y is None:
            return x
        return x, self.y[idx]
    
class NeuralNet(nn.Module):
    
    def __init__(
            self,
            in_features: int,
            out_features: int,
            hidden_dim: int,
            num_layers: int,
            dropout_p: float = 0.2
    ):
        super(NeuralNet, self).__init__()

        self.in_features = in_features
        self.out_features = out_features
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.dropout_p    = dropout_p

        self.model_layers = self.build_model()
        self.model = nn.Sequential(*self.model_layers)
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        
        out = self.model(x)

        return out
    
    def build_model(self):
        layer_list = []

        for l in range(self.num_layers):
            # Determine dims for this layer
            if l == 0:
                in_dim, out_dim = self.in_features, self.hidden_dim
            elif l == self.num_layers - 1:
                in_dim, out_dim = self.hidden_dim, self.out_features
            else:
                in_dim = out_dim = self.hidden_dim

            # Linear
            layer_list.append(nn.Linear(in_dim, out_dim))

            # If not final layer, add BN, activation, dropout
            if l < self.num_layers - 1:
                layer_list.append(nn.BatchNorm1d(out_dim))
                layer_list.append(nn.ReLU())
                #layer_list.append(nn.Dropout(self.dropout_p))

        return layer_list
    
input_list = []
output_list = []

num_batches = 200
for i in range(num_batches):
    batch = np.load(f"/gpfs/bwfor/work/ws/hd_gy283-my_data/sm_batches_1e6_vonMises_beta/batch_1e6_{i}.npz")
    _input = batch["inputs"]
    _output = batch["currents"]
    input_list.append(_input)
    output_list.append(_output)


raw_inputs = np.concatenate(input_list)
outputs = np.concatenate(output_list)
inputs = raw_inputs[:, 1:]
print(f"raw_inputs shape: {raw_inputs.shape}")
print(f"outputs shape: {outputs.shape}")
print(f"inputs shape: {inputs.shape}")

X_train, X_test, y_train, y_test = train_test_split(inputs, outputs, test_size=0.2, random_state=42, shuffle=True)
train_set = MakeDataset(X_train, y_train)
test_set = MakeDataset(X_test, y_test)

"""eps = 1e-8
X_train_mean = X_train.mean(0)
X_train_std = X_train.std(0) + eps

y_train_mean = y_train.mean(0)
y_train_std = y_train.std(0) + eps

X_train_norm = (X_train - X_train_mean) / X_train_std
X_test_norm = (X_test - X_train_mean) / X_train_std

y_train_norm = (y_train - y_train_mean) / y_train_std
y_test_norm = (y_test - y_train_mean) / y_train_std

train_set = MakeDataset(X_train_norm, y_train_norm)
test_set = MakeDataset(X_test_norm, y_test_norm)"""

batch_size = 512

train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
test_loader  = DataLoader(test_set,  batch_size=batch_size, shuffle=False)
# Out:
# cuda
# raw_inputs shape: (200000, 8)
# outputs shape: (200000,)
# inputs shape: (200000, 7)

# %%
X_mean = torch.from_numpy(X_train_mean).float()
X_std  = torch.from_numpy(X_train_std).float()
y_mean = torch.tensor(y_train_mean).float()
y_std  = torch.tensor(y_train_std).float()

in_features = 7
out_features = 1
hidden_dim = 90
num_layers = 10

model = NeuralNet(in_features=in_features, out_features=out_features, hidden_dim=hidden_dim, num_layers=num_layers)

state_dict = torch.load(f="../../SM_1e6_vonMises_beta_0.pth", map_location=torch.device("cpu"))

model.load_state_dict(state_dict=state_dict)
model.eval()

sim_curve = np.load("/gpfs/bwfor/work/ws/hd_gy283-my_data/example_curves/vonMises_beta_SM.npz")
curve = sim_curve["current"]
control_volts = sim_curve["control"]

vs_ = torch.linspace(-1.5, 1.5, 100)

n = 100
vs = torch.linspace(-1.5, 1.5, n)

control_volts[0] = 0.0
control_volts[1] = 0.0
print(control_volts)
raw_volts = torch.from_numpy(control_volts).float().unsqueeze(0).repeat(n, 1)
x = raw_volts[:, 1:]
x[:, 0] = vs
#print(x)

x_norm = x#(x - X_mean) / X_std

with torch.no_grad():
    out = model(x_norm)# * y_std + y_mean

plot_kwargs = {
    "lw": 3.5,
    "alpha": 0.75
}

out_norm = (out - out.mean()) / out.std()
fig, ax = plt.subplots(figsize=(8, 8))
ax.scatter(vs_, curve)
ax.plot(vs, out.detach(), **plot_kwargs, zorder=3)

ax = plt.gca()
ax.grid(True)
ax.set_facecolor("lightgrey")
ax.xaxis.grid(color="w", lw=1.)
ax.yaxis.grid(color="w", lw=1.)
ax.xaxis.set_tick_params(width=2)
ax.yaxis.set_tick_params(width=2)
ax.spines[['top', 'bottom', 'right', 'left']].set_linewidth(2)
# Out:
# [ 0.   0.   0.1 -1.2  0.9 -0.6 -1.4  1.5]

# %%
# --- Frozen wrapper around your pretrained model ---
class Net(nn.Module):
    def __init__(self, model):
        super().__init__()
        self.model = model
    def forward(self, x):
        return self.model(x)

# model, X_mean, X_std, y_mean, y_std must already be defined from training time:
# X_mean: (7,), X_std: (7,), y_mean: (), y_std: ()
# If yours are numpy arrays, convert to torch below.

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.eval()
for p in model.parameters():
    p.requires_grad = False
model.to(device)

# Ensure stats are torch tensors on the right device
X_mean = X_mean.clone().detach().float().to(device)   # shape (7,)
X_std  = X_std.clone().detach().float().to(device)
y_mean = y_mean.clone().detach().float().to(device)   # shape ()
y_std  = y_std.clone().detach().float().to(device)

net = Net(model).to(device)
for p in net.parameters():
    p.requires_grad = False
net.eval()  # important if model has BN/Dropout

# ---- Data: we define the target in RAW space, then compare in RAW space ----
N = 2048
input_voltage = torch.linspace(-1.5, 1.5, N).unsqueeze(1)  # (N,1) raw space
temp = 5
y_true = input_voltage**2  # raw-space target; use sigmoid if you prefer

dataset = torch.utils.data.TensorDataset(input_voltage, y_true)
loader = torch.utils.data.DataLoader(dataset, batch_size=64, shuffle=True)

# ---- Trainable 6 control voltages in RAW space ----
min_voltage, max_voltage = -1.5, 1.5
init = (max_voltage - min_voltage) * torch.rand(1, 6, device=device) + min_voltage
control_voltages = nn.Parameter(init)  # (1,6), raw space

opt = optim.Adam([control_voltages], lr=1e-3, weight_decay=1e-3)
loss_fn = nn.MSELoss()

epochs = 1000
for epoch in range(epochs):
    running = 0.0
    count = 0
    for x_batch_cpu, y_batch_cpu in loader:
        # Move minibatch to device
        x_batch = x_batch_cpu.to(device)  # (B,1) raw
        y_batch = y_batch_cpu.to(device)  # (B,1) raw
        B = x_batch.size(0)

        # Expand shared controls and build 7-D RAW input
        cvs = control_voltages.expand(B, -1)  # (B,6) raw

        # If training order was [swept_voltage, control_0..5]:
        x_raw = torch.cat([x_batch, cvs], dim=1)  # (B,7)
        
        # ---- If your training order was DIFFERENT (e.g., controls first, swept last),
        # reorder here. For example, [control_0..5, swept_voltage]:
        # x_raw = torch.cat([cvs, x_batch], dim=1)
        # Make sure X_mean/X_std match this order exactly.

        # Normalize inputs with training stats
        x_norm = (x_raw - X_mean) / X_std

        # Forward: model outputs NORMALIZED prediction
        pred_norm = net(x_norm)               # (B,1) normalized
        # De-normalize to RAW to compare with raw y
        pred_raw = pred_norm * y_std + y_mean # (B,1) raw

        loss = loss_fn(pred_raw, y_batch)

        opt.zero_grad()
        loss.backward()
        opt.step()

        # Keep controls in valid RAW range
        with torch.no_grad():
            control_voltages.clamp_(min_voltage, max_voltage)

        running += loss.item() * B
        count += B

    if (epoch + 1) % 50 == 0:
        print(f"Epoch {epoch+1}: MSE={running / count:.6f}")

print("Learned 6 control_volts (RAW):", control_voltages.detach().cpu().numpy())
# Out:
# Epoch 50: MSE=0.652706
# Epoch 100: MSE=0.530180
# Epoch 150: MSE=0.529149
# Epoch 200: MSE=0.529148
# Epoch 250: MSE=0.529149
# Epoch 300: MSE=0.529148
# Epoch 350: MSE=0.529150
# Epoch 400: MSE=0.529152
# Epoch 450: MSE=0.529150
# Epoch 500: MSE=0.529151
# Epoch 550: MSE=0.529158
# Epoch 600: MSE=0.529152
# Epoch 650: MSE=0.529151
# Epoch 700: MSE=0.529153
# Epoch 750: MSE=0.529149
# Epoch 800: MSE=0.529150
# Epoch 850: MSE=0.529158
# Epoch 900: MSE=0.529153
# Epoch 950: MSE=0.529153
# Epoch 1000: MSE=0.529155
# Learned 6 control_volts (RAW): [[1.5        0.10841371 1.2926065  1.5        1.5        1.5       ]]

# %%
num_of_points = 100
expanded_control_voltages = control_voltages.detach().cpu().expand(num_of_points, -1)
print(expanded_control_voltages.shape)
voltage_range = torch.linspace(-1.5, 1.5, num_of_points).unsqueeze(1)
print(voltage_range.shape)

voltages = torch.cat([voltage_range, expanded_control_voltages], axis=-1).to(device)
print(voltages.shape)

currents = model(voltages).detach().cpu() * y_std.cpu() + y_mean.cpu()
plt.scatter(voltage_range, currents, c="midnightblue", alpha=.6)
#plt.plot(voltage_range, torch.sigmoid(temp*voltage_range), linestyle="dashed")
#plt.plot(voltage_range, voltage_range, linestyle="dashed")
plt.plot(voltage_range, voltage_range**2, linestyle="dashed")
# Out:
# torch.Size([100, 6])
# torch.Size([100, 1])
# torch.Size([100, 7])

# %%
import matplotlib.pyplot as plt
import os
os.environ['KERAS_BACKEND'] = 'torch'
import bayesflow as bf
import numpy as np

from scipy.stats import qmc
# Out:
# INFO:bayesflow:Using backend 'torch'
# WARNING:bayesflow:
# When using torch backend, we need to disable autograd by default to avoid excessive memory usage. Use
#
# with torch.enable_grad():
#     ...
#
# in contexts where you need gradients (e.g. custom training loops).

# %%
d = 6
sampler = qmc.LatinHypercube(d=d)

l_bounds = d*[-1.5]
u_bounds = d*[1.5]

# %%
def prior():
    parameters = sampler.random()
    parameters_scaled = qmc.scale(parameters, l_bounds, u_bounds)
    return {"parameters": parameters_scaled[0]}

# %%
def likelihood(parameters):
    n = 10
    x = np.linspace(-1.5, 1.5, n)
    input_parameters = parameters[None].repeat(n, axis=0)
    input = np.concatenate([x[:, None], input_parameters], axis=-1)
    out = model(torch.from_numpy(input).float())

    return {"observables": out.numpy()[..., 0]}

# %%
likelihood(**prior())
# Out:
# {'observables': array([-0.25016278, -0.26343286, -0.277174  , -0.2749573 , -0.1980777 ,
#          0.0144648 ,  0.12724642,  0.20980218,  0.25799173,  0.2502151 ],
#        dtype=float32)}

# %%
simulator = bf.make_simulator([prior, likelihood])

# %%
# %%time
test_data = simulator.sample(32)
# Out:
# CPU times: user 12.5 ms, sys: 1.38 ms, total: 13.9 ms
# Wall time: 13 ms

# %%
validation_data = simulator.sample(32)

# %%
workflow = bf.BasicWorkflow(simulator=simulator, inference_conditions="observables", inference_variables="parameters")
history = workflow.fit_online(num_batches_per_epoch=500, epochs=100, batch_size=32, validation_data=validation_data)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OnlineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 38s 76ms/step - loss: 7.6180 - val_loss: 6.9527
# Epoch 2/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 38s 76ms/step - loss: 7.0155 - val_loss: 6.8074
# Epoch 3/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 38s 76ms/step - loss: 6.6634 - val_loss: 6.2023
# Epoch 4/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 38s 76ms/step - loss: 6.2530 - val_loss: 5.7373
# Epoch 5/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 38s 76ms/step - loss: 5.9769 - val_loss: 5.6118
# Epoch 6/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 38s 76ms/step - loss: 5.8005 - val_loss: 5.4202
# Epoch 7/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 38s 76ms/step - loss: 5.6175 - val_loss: 5.2922
# Epoch 8/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 38s 76ms/step - loss: 5.5103 - val_loss: 5.2918
# Epoch 9/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 38s 76ms/step - loss: 5.3711 - val_loss: 5.3056
# Epoch 10/100
# ...

# %%
workflow.plot_default_diagnostics(100)
# Out:
# {'losses': <Figure size 1600x400 with 1 Axes>,
#  'recovery': <Figure size 3000x500 with 6 Axes>,
#  'calibration_ecdf': <Figure size 3000x500 with 6 Axes>,
#  'z_score_contraction': <Figure size 3000x500 with 6 Axes>}

# %%
test_data = simulator.sample(1)

# %%
plt.plot(test_data["observables"][0])

# %%
samples = workflow.sample(num_samples=10, conditions=test_data)

# %%
samples
# Out:
# {'parameters': array([[[-0.92015386,  0.27226421, -0.49033296, -0.27006257,
#           -1.51089239, -0.66146553],
#          [-1.24294615, -0.67500216,  0.70213366,  0.09222868,
#           -0.7059536 , -1.42831862],
#          [-1.18678248, -0.4275322 , -0.77123123, -0.10589485,
#           -1.04428005, -0.35327017],
#          [-1.46236336,  0.34446636, -0.99382937, -1.38702393,
#            0.70250893, -0.76695114],
#          [-1.32545316,  0.49395832, -1.73722196, -0.43490267,
#           -0.69750351, -0.46955347],
#          [ 0.26895985, -1.63307607, -1.35699701, -0.44308755,
#            0.17251526, -1.06132782],
#          [-1.34067178, -1.05423152, -0.01774736,  0.19299361,
#           -0.74547756, -0.54684114],
#          [-1.52882218, -0.26972696, -0.70996153, -0.39784339,
#            1.29649353, -1.04303658],
#          [ 1.08199263, -0.2863279 , -0.33396444, -1.49230003,
#           -1.30827904, -0.59533864],
# ...

# %%
for p in samples['parameters'][0]:
    plt.plot(likelihood(p)["observables"])
plt.plot(test_data["observables"][0], color="black", linestyle="dashed")
