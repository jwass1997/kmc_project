# %%
import numpy as np
from pathlib import Path
from jobs import slurm_single_IV
import torch

print(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
# Out:
# cuda

# %%
import os, socket, pathlib, shutil, subprocess

print("HOSTNAME:", socket.gethostname())
print("PWD:", os.getcwd())
print("which sbatch:", shutil.which("sbatch"))
print("/usr/bin/sbatch exists:", pathlib.Path("/usr/bin/sbatch").exists())
print("list /usr/bin/sbatch:", subprocess.run(["bash","-lc","ls -l /usr/bin/sbatch || echo MISSING"], capture_output=True, text=True).stdout)
# Out:
# HOSTNAME: o03c01
# PWD: /home/hd/hd_hd/hd_gy283/kmc_project/scripts/python_scripts
# which sbatch: None
# /usr/bin/sbatch exists: False
# list /usr/bin/sbatch: MISSING

# %%
input_index = 1
func_type = 'Sine'
lam = 0.0

slurm_single_IV(
        numOfPoints=50,
        inputIdx=input_index+1,
        outputIdx=0,
        control_indices=[1, 2, 3, 5, 6, 7],
        control_volts=[ 0.1521,  0.6498,  0.5481, -0.0670, -0.1069,  0.3896],
        minVoltage=-1.5,
        maxVoltage=1.5,
        eq_steps=100_000,
        sim_steps=1_000_000,
        num_intervals=100,
        seed=np.random.randint(low=1, high=2**30),
        cfg=Path(f"/gpfs/bwfor/work/ws/hd_gy283-my_data_recover/final_datasets/data_vMB_ring_1e7/configs/config.txt"),
        acc_cfg=Path(f"/gpfs/bwfor/work/ws/hd_gy283-my_data_recover/final_datasets/data_vMB_ring_1e7/configs/vMB_ring.txt"),
        don_cfg=Path(f"/gpfs/bwfor/work/ws/hd_gy283-my_data_recover/final_datasets/data_vMB_ring_1e7/configs/uniform_donors_1.txt"),
        ele_cfg=Path(f"/gpfs/bwfor/work/ws/hd_gy283-my_data_recover/final_datasets/data_vMB_ring_1e7/configs/electrodes.txt"),
        save_folder=Path("/gpfs/bwfor/work/ws/hd_gy283-my_data_recover/1d_funcs_BO"),
        file_name=Path(f"BO_func_type={func_type}_data_type=uni_1e7_lam={lam}_input_idx={input_index-1}"),
        BINARY=Path("/home/hd/hd_hd/hd_gy283/kmc_project/build/kmc_project"),
        SH_SCRIPT=Path("/home/hd/hd_hd/hd_gy283/kmc_project/scripts/slurm/single_curve.sh"),
        OUT_DIR=Path("/home/hd/hd_hd/hd_gy283/kmc_project/slurm_out")
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 5
#       2 func_type = 'Sine'
#       3 lam = 0.0
# ----> 5 slurm_single_IV(
#       6         numOfPoints=50,
#       7         inputIdx=input_index+1,
#       8         outputIdx=0,
#       9         control_indices=[1, 2, 3, 5, 6, 7],
#      10         control_volts=[ 0.1521,  0.6498,  0.5481, -0.0670, -0.1069,  0.3896],
#      11         minVoltage=-1.5,
#      12         maxVoltage=1.5,
#      13         eq_steps=100_000,
#      14         sim_steps=1_000_000,
#      15         num_intervals=100,
#      16         seed=np.random.randint(low=1, high=2**30),
#      17         cfg=Path(f"/gpfs/bwfor/work/ws/hd_gy283-my_data_recover/final_datasets/data_vMB_ring_1e7/configs/config.txt"),
#      18         acc_cfg=Path(f"/gpfs/bwfor/work/ws/hd_gy283-my_data_recover/final_datasets/data_vMB_ring_1e7/configs/vMB_ring.txt"),
#      19         don_cfg=Path(f"/gpfs/bwfor/work/ws/hd_gy283-my_data_recover/final_datasets/data_vMB_ring_1e7/configs/uniform_donors_1.txt"),
#      20         ele_cfg=Path(f"/gpfs/bwfor/work/ws/hd_gy283-my_data_recover/final_datasets/data_vMB_ring_1e7/configs/electrodes.txt"),
#      21         save_folder=Path("/gpfs/bwfor/work/ws/hd_gy283-my_data_recover/1d_funcs_BO"),
#      22         file_name=Path(f"BO_func_type={func_type}_data_type=uni_1e7_lam={lam}_input_idx={input_index-1}"),
#      23         BINARY=Path("/home/hd/hd_hd/hd_gy283/kmc_project/build/kmc_project"),
#      24         SH_SCRIPT=Path("/home/hd/hd_hd/hd_gy283/kmc_project/scripts/slurm/single_curve.sh"),
#      25         OUT_DIR=Path("/home/hd/hd_hd/hd_gy283/kmc_project/slurm_out")
#      26 )
#
# File ~/kmc_project/scripts/python_scripts/jobs.py:130, in slurm_single_IV(numOfPoints, inputIdx, outputIdx, control_indices, control_volts, minVoltage, maxVoltage, eq_steps, sim_steps, num_intervals, seed, cfg, acc_cfg, don_cfg, ele_cfg, save_folder, file_name, BINARY, SH_SCRIPT, OUT_DIR)
#     104 args = [
#     105     #"sbatch",
#     106     SBATCH,
#    (...)
#     125     f"--fileName={file_name}"
#     126 ]
#     128 cmd = args + control_volts_args
# --> 130 result = subprocess.run(cmd, capture_output=True, text=True)
#     131 print("Running command:", " ".join(cmd))
#     132 if result.returncode != 0:
#
# File ~/.conda/envs/py311/lib/python3.11/subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     545     kwargs['stdout'] = PIPE
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#     550         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File ~/.conda/envs/py311/lib/python3.11/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/.conda/envs/py311/lib/python3.11/subprocess.py:1955, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1953     err_msg = os.strerror(errno_num)
#    1954 if err_filename is not None:
# -> 1955     raise child_exception_type(errno_num, err_msg, err_filename)
#    1956 else:
#    1957     raise child_exception_type(errno_num, err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/bin/sbatch'
