# %%
import matplotlib.pyplot as plt
import os
os.environ['KERAS_BACKEND'] = 'torch'
import bayesflow as bf
# Out:
# INFO:bayesflow:Using backend 'jax'

# %%
import numpy as np

# %%
data = np.load(f"/gpfs/bwfor/work/ws/hd_gy283-my_data/sm_batches_1e7/batch_1e7_0.npz")
#print(data["currents"])
print(data["inputs"][0])
# Out:
# [ 0.         -0.77423097  1.13766788  0.28969515  0.52417656  0.89557139
#   0.2612938  -1.39203126]
