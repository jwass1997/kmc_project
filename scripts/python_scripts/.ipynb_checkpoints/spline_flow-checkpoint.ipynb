# %%
import torch
import torch.nn as nn
import numpy as np
from tqdm import tqdm

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
from pathlib import Path

num_batches = 200

data_dir = Path('/gpfs/bwfor/work/ws/hd_gy283-my_data/data/data_uni_nf/')

coord_list = []
current_list = []
voltage_list = []
input_idx = 0

for i in range(num_batches):
    fp = data_dir / f'dataset_batch_{i:04d}.pt'
    data = torch.load(fp, weights_only=False, map_location='cpu')
    coord_list.append(data['X'])
    current_list.append(data['y'])
    voltage_list.append(data['V'][..., input_idx].reshape(-1, 1))

coord_set = np.concatenate(coord_list)
current_set = np.concatenate(current_list)
voltage_set = np.concatenate(voltage_list)

print('Dataset loaded')
# Out:
# Dataset loaded

# %%
from torch.utils.data import Dataset, TensorDataset, DataLoader
from torch.utils.data import random_split
from train_sm import MakeDataset

train_size = 0.8
val_size = 0.1
test_size = 0.1

r2 = np.sum(coord_set**2, axis=-1)
print(r2.max())
idx = np.argsort(r2, axis=1)
sorted_coord_set = np.take_along_axis(
    coord_set,
    idx[..., None],
    axis=1
)

X = torch.from_numpy(sorted_coord_set).float()
C = torch.from_numpy(np.concatenate([voltage_set, current_set.reshape(-1, 1)], axis=1)).float()

X = X[:10000, ...]
C = C[:10000, ...]

print(current_set.max(), current_set.min())

print(X.shape)
print(C.shape)

dataset = TensorDataset(X, C)

generator_1 = torch.Generator().manual_seed(666)
train_ds, val_ds, test_ds = random_split(dataset, lengths=[train_size, val_size, test_size], generator=generator_1)

batch_size = 512
train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=6, pin_memory=True)
val_loader = DataLoader(val_ds, batch_size=batch_size, shuffle=False, num_workers=6, pin_memory=True)
test_loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False, num_workers=6, pin_memory=True)

print(len(train_loader.dataset))
print(len(val_loader.dataset))
print(len(test_loader.dataset))
print('Dataloaders ready')
# Out:
# 0.99999994
# 1.1268212 -0.9519929
# torch.Size([10000, 200, 2])
# torch.Size([10000, 2])
# 8000
# 1000
# 1000
# Dataloaders ready

# %%
import normflows as nf

K = 16

latent_size = 400
hidden_units = 128
hidden_layers = 5

flows = []
for i in range(K):
    flows += [nf.flows.AutoregressiveRationalQuadraticSpline(latent_size, hidden_layers, hidden_units)]
    flows += [nf.flows.LULinearPermute(latent_size)]

q0 = nf.distributions.DiagGaussian(latent_size, trainable=False)
    
nfm = nf.NormalizingFlow(q0=q0, flows=flows)

nfm = nfm.to(device)

# %%
num_epochs = 50

optimizer = torch.optim.Adam(nfm.parameters(), lr=1e-3)

train_losses = []
val_losses = []

with tqdm(total=num_epochs, desc="Epochs") as pbar:
    for epoch in range(1, num_epochs + 1):
    
        nfm.train()
        train_loss = 0.0
        n_train = 0
        for x, c in train_loader:
            x = x.reshape(-1, 200*2)
            x = x.to(device)       
            c = c.to(device)
    
            loss = nfm.forward_kld(x)
    
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
    
            batch_size = x.size(0)
            train_loss += loss.item() * batch_size
            n_train += batch_size

        train_loss /= n_train
        train_losses.append(train_loss)
    
        nfm.eval()
        val_loss = 0.0
        n_val = 0
    
        with torch.no_grad():
            for x_val, c_val in val_loader:
                x_val = x_val.reshape(-1, 200*2)
                x_val = x_val.to(device)
                c_val = c_val.to(device)
    
                loss_val = nfm.forward_kld(x_val)
                
                batch_size = x_val.size(0)
                val_loss += loss_val.item() * batch_size
                n_val += batch_size
    
        val_loss /= n_val
        val_losses.append(val_loss)
    
        pbar.set_postfix({
            "Epoch": f"{epoch:03d}",
            "train NLL": f"{train_loss:.4f}",
            "val NLL": f"{val_loss:.4f}"
        })
        pbar.update(1)
# Out:
# Epochs:   8%|▊         | 4/50 [00:27<05:14,  6.84s/it, Epoch=004, train NLL=131.0960, val NLL=154.7431]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 19
#      16 x = x.to(device)
#      17 c = c.to(device)
# ---> 19 loss = nfm.forward_kld(x)
#      21 optimizer.zero_grad()
#      22 loss.backward()
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/normflows/core.py:99, in NormalizingFlow.forward_kld(self, x)
#      97 z = x
#      98 for i in range(len(self.flows) - 1, -1, -1):
# ---> 99     z, log_det = self.flows[i].inverse(z)
#     100     log_q += log_det
#     101 log_q += self.q0.log_prob(z)
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/normflows/flows/neural_spline/wrapper.py:235, in AutoregressiveRationalQuadraticSpline.inverse(self, z, context)
#     234 def inverse(self, z, context=None):
# --> 235     z, log_det = self.mprqat(z, context=context)
#     236     return z, log_det.view(-1)
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/normflows/flows/affine/autoregressive.py:26, in Autoregressive.forward(self, inputs, context)
#      24 def forward(self, inputs, context=None):
#      25     autoregressive_params = self.autoregressive_net(inputs, context)
# ---> 26     outputs, logabsdet = self._elementwise_forward(inputs, autoregressive_params)
#      27     return outputs, logabsdet
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/normflows/flows/neural_spline/autoregressive.py:131, in MaskedPiecewiseRationalQuadraticAutoregressive._elementwise_forward(self, inputs, autoregressive_params)
#     130 def _elementwise_forward(self, inputs, autoregressive_params):
# --> 131     return self._elementwise(inputs, autoregressive_params)
#
# File ~/.conda/envs/py311/lib/python3.11/site-packages/normflows/flows/neural_spline/autoregressive.py:116, in MaskedPiecewiseRationalQuadraticAutoregressive._elementwise(self, inputs, autoregressive_params, inverse)
#     113     spline_fn = splines.unconstrained_rational_quadratic_spline
#     114     spline_kwargs = {"tails": self.tails, "tail_bound": self.tail_bound}
# --> 116 outputs, logabsdet = spline_fn(
#     117     inputs=inputs,
#     118     unnormalized_widths=unnormalized_widths,
#     119     unnormalized_heights=unnormalized_heights,
#     120     unnormalized_derivatives=unnormalized_derivatives,
#     121     inverse=inverse,
#     122     min_bin_width=self.min_bin_width,
#     123     min_bin_height=self.min_bin_height,
#     124     min_derivative=self.min_derivative,
#     125     **spline_kwargs
#     126 )
#     128 return outputs, utils.sum_except_batch(logabsdet)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

torch.save(nfm.state_dict(), f='/gpfs/bwfor/work/ws/hd_gy283-my_data/models/spline_flow.pth')
plt.plot(train_losses)
plt.plot(val_losses)
nfm.eval()

num_samples = 100

with torch.no_grad():
    x, _ = nfm.sample(num_samples=100)

x = x.detach().cpu().numpy().reshape(-1, 200, 2)
print(x.shape)
# Out:
# (100, 200, 2)

# %%
x_coords = x.reshape(-1, 2)
radii = np.linalg.norm(x, axis=-1)
thetas = np.atan2(x[..., 1], x[..., 0])

bins=10
fig, ax = plt.subplots(ncols=2)
ax[0].hist(radii**2, bins=bins)
ax[1].hist(thetas, bins=bins)
plt.show()
# Out:
# (100, 200, 2)

# %%
import matplotlib.patches as ps

fig, ax = plt.subplots()
ax.set_box_aspect(1)
ax.add_patch(ps.Circle(xy=(0,0), radius=1.0, fill=None))
ax.scatter(*x.T, s=1.5, alpha=.4)
