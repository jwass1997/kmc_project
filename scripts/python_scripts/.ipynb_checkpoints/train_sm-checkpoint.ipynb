# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import numpy as np
import matplotlib.pyplot as plt
import argparse
from pathlib import Path
from argparse import Namespace
from sklearn.model_selection import train_test_split
from train_sm import MakeDataset, create_data_loaders, EarlyStopping, train_val_test_loaders
from utils import pred_vs_true
from sm import NeuralNet

#torch.set_float32_matmul_precision('high')  # allows TF32
#torch.backends.cuda.matmul.allow_tf32 = True
#torch.backends.cudnn.allow_tf32 = True

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

args = Namespace(
    data_dir=Path(f"/gpfs/bwfor/work/ws/hd_gy283-my_data/data_vMB_own_pde_solver/"),
    num_batches=200,
    batch_size=512,
    x_mean=None,
    x_std=None,
    y_mean=None,
    y_std=None,
    layer_dims=[7, 90, 90, 90, 1],
    num_epochs=100,
    lr=1e-3,
    save_name=Path(f"/gpfs/bwfor/work/ws/hd_gy283-my_data/models/sm_vMB"),
)

output_idx = 0
data_dict = train_val_test_loaders(args.data_dir, output_idx, args.num_batches, args.batch_size, random_state=np.random.randint(0, 2**31 - 1))
#print(data_dict.keys())

train_loader = data_dict['train_loader']
val_loader = data_dict['val_loader']
args.x_mean = data_dict['X_train_mean']
args.x_std = data_dict['X_train_std']
args.y_mean = data_dict['y_train_mean']
args.y_std = data_dict['y_train_std']

print(args)

model = NeuralNet(args.layer_dims, args.x_mean, args.x_std, args.y_mean, args.y_std, dropout_p=0.1).to(device)
print(model)
# Out:
# cuda
# Namespace(data_dir=PosixPath('/gpfs/bwfor/work/ws/hd_gy283-my_data/data_uni_samples_1e6'), num_batches=200, batch_size=512, x_mean=array([-0.00049972, -0.00011895,  0.003808  , -0.0003865 , -0.00109595,
#         0.0011836 , -0.00103707]), x_std=array([0.86630086, 0.86606328, 0.8661107 , 0.86575872, 0.86670962,
#        0.86603364, 0.86657592]), y_mean=np.float64(-0.019808889931973956), y_std=np.float64(0.2159862668179182), layer_dims=[7, 90, 90, 90, 1], num_epochs=100, lr=0.001, save_name=PosixPath('/gpfs/bwfor/work/ws/hd_gy283-my_data/models/sm_samples'))
# NeuralNet(
#   (model): Sequential(
#     (0): Linear(in_features=7, out_features=90, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#     (2): BatchNorm1d(90, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#     (4): Linear(in_features=90, out_features=90, bias=True)
#     (5): Dropout(p=0.1, inplace=False)
#     (6): BatchNorm1d(90, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU()
#     (8): Linear(in_features=90, out_features=90, bias=True)
#     (9): Dropout(p=0.1, inplace=False)
#     (10): BatchNorm1d(90, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU()
#     (12): Linear(in_features=90, out_features=1, bias=True)
#   )
# )

# %%
#model = torch.compile(model)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=args.lr)
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer=optimizer, step_size=200, gamma=0.1)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=100, T_mult=2, eta_min=1e-4)

train_losses = []
val_losses = []

early_stopping = EarlyStopping(patience=10, min_delta=0.0001)

for epoch in range(1, args.num_epochs+1):

    model.train()
    running_loss = 0.0
    for inputs_batch, targets_batch in train_loader:
        
        inputs_batch  = inputs_batch.to(device, non_blocking=True).float()
        targets_batch = targets_batch.to(device, non_blocking=True).float()
        
        targets_batch = (targets_batch - model.y_mean) / model.y_std
        
        optimizer.zero_grad()
        preds = model(inputs_batch)

        loss  = criterion(preds, targets_batch)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs_batch.size(0)

    epoch_train_loss = running_loss / len(train_loader.dataset)

    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for inputs_batch, targets_batch in val_loader:
            
            inputs_batch  = inputs_batch.to(device, non_blocking=True).float()
            targets_batch = targets_batch.to(device, non_blocking=True).float()

            targets_batch = (targets_batch - model.y_mean) / model.y_std

            preds = model(inputs_batch)

            loss  = criterion(preds, targets_batch)
            val_loss += loss.item() * inputs_batch.size(0)

    epoch_val_loss = val_loss / len(val_loader.dataset)
    #scheduler.step()

    train_losses.append(epoch_train_loss)
    val_losses.append(epoch_val_loss)
    current_lr = optimizer.param_groups[0]['lr']
    if epoch % 10 == 0:
        print(f"Epoch {epoch:2d}/{args.num_epochs} "
              f"Train Loss: {epoch_train_loss:.10f}"
              f" | Val Loss: {epoch_val_loss:.10f}"
              f" | LR: {current_lr}", flush=True)
    #early_stopping(epoch_val_loss)
    if early_stopping.early_stop:
        print("[EARLY STOPPING TRIGGERED]")
        break

torch.save({
    "model_state_dict": model.state_dict(),
    "args": vars(args),
    "train_losses": train_losses,
    "val_losses": val_losses
}, f"{args.save_name}.pth")

print(f"Model has been saved!")
# Out:
# Epoch 10/100 Train Loss: 0.2134807312 | Val Loss: 0.2109166682 | LR: 0.001
# Epoch 20/100 Train Loss: 0.2075822892 | Val Loss: 0.1989642152 | LR: 0.001
# Epoch 30/100 Train Loss: 0.2057990850 | Val Loss: 0.2010079182 | LR: 0.001
# Epoch 40/100 Train Loss: 0.2048428289 | Val Loss: 0.2064505855 | LR: 0.001
# Epoch 50/100 Train Loss: 0.2041842561 | Val Loss: 0.2016598800 | LR: 0.001
# Epoch 60/100 Train Loss: 0.2025486126 | Val Loss: 0.1980356815 | LR: 0.001
# Epoch 70/100 Train Loss: 0.2029250188 | Val Loss: 0.1982651377 | LR: 0.001
# Epoch 80/100 Train Loss: 0.2028014188 | Val Loss: 0.1993205738 | LR: 0.001
# Epoch 90/100 Train Loss: 0.2023876341 | Val Loss: 0.1954196842 | LR: 0.001
# Epoch 100/100 Train Loss: 0.2023052887 | Val Loss: 0.1991947560 | LR: 0.001
# Model has been saved!

# %%
state_dict = torch.load("/gpfs/bwfor/work/ws/hd_gy283-my_data/models/sm_samples.pth", map_location="cpu", weights_only=False)
args = state_dict['args']
model_state_dict = state_dict['model_state_dict']

net = NeuralNet(args['layer_dims'], args['x_mean'], args['x_std'], args['y_mean'], args['y_std'], dropout_p=0.1, batch_norm=True)
net.load_state_dict(model_state_dict)

fig, ax = plt.subplots()

test_set = data_dict['test_set']

test_input = test_set[0]
#test_input = (test_set[0] - net.x_mean) / net.x_std
test_target = (test_set[1] - net.y_mean) / net.y_std 
pred_vs_true(ax, test_input, test_target, net)
plt.show()

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from mpl_toolkits.axes_grid1 import make_axes_locatable
from sm import NeuralNet

#state_dict = torch.load("/gpfs/bwfor/work/ws/hd_gy283-my_data/models/sm_uni_n_a=200.pth", map_location="cpu", weights_only=False)
state_dict = torch.load("/gpfs/bwfor/work/ws/hd_gy283-my_data/models/sm_uni_samples_1e6.pth", map_location="cpu", weights_only=False)
args = state_dict['args']
model_state_dict = state_dict['model_state_dict']

net = NeuralNet(args['layer_dims'], args['x_mean'], args['x_std'], args['y_mean'], args['y_std'])
net.load_state_dict(model_state_dict)

y_true = []

net.eval()

num_batches = 300
y_true_list = []
x_in = []

for i in range(90, 100):
    #data = np.load(f"/gpfs/bwfor/work/ws/hd_gy283-my_data/data_uni/batch_{i}.npz")
    data = np.load(f"/gpfs/bwfor/work/ws/hd_gy283-my_data/data_uni_samples_1e6/batch_{i}.npz")
    #output_idx = data["outputIdx"][0]
    x, y = data["inputs"], data["currents"][:, output_idx]
    x_in.append(x[:, output_idx+1:])
    y_true_list.append(y)

input_tensor = torch.tensor(np.concatenate(x_in, axis=0), dtype=torch.float32)

with torch.no_grad():
    y_pred = net(input_tensor).detach().cpu()
y_true = np.concatenate(y_true_list, axis=0)[:, None]

y_pred = (y_pred - net.y_mean.numpy()) / net.y_std.numpy()
y_true = (y_true - net.y_mean.numpy()) / net.y_std.numpy()

l_bound = -1.5
u_bound = 1.5
#z = l_bound + (u_bound - l_bound) * torch.rand(num_points, net.layer_dims[0])

def pred_vs_true(ax, y_pred, y_true, bins=140, use_log=True):

    y_pred = np.asarray(y_pred).ravel()
    y_true = np.asarray(y_true).ravel()

    pad = 0.1
    min_val = float(min(y_true.min(),y_pred.min())) + pad
    max_val = float(max(y_true.max(),y_pred.max())) + pad

    norm = LogNorm()
    
    _, _, _, im = ax.hist2d(y_pred, y_true, bins=bins, range=[[min_val, max_val], [min_val, max_val]], norm=norm, cmap="RdBu", zorder=5)
    
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="3%", pad=0.1)  # 3% of ax width
    ax.figure.colorbar(im, cax=cax)
    
    #ax.scatter(y_pred, y_true, s=4, edgecolors="blue", facecolor=None)
    ax.spines[:].set_linewidth(1.5)
    ax.tick_params(which='major', direction='in', width=1.5)
    ax.set_aspect('equal')
    ax.grid(linestyle='--', c='w')
    ax.set_facecolor('lightgray')

    ax.set_xlabel(r'$I_{\mathrm{pred}}$ $[ \nu_0 e_0 ]$')
    ax.set_ylabel(r'$I_{\mathrm{true}}$ $[ \nu_0 e_0 ]$')

    #ax.plot([min_val, min_val], [max_val, max_val])

    return ax
# Out:
# /tmp/ipykernel_2543126/111629224.py:39: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   y_pred = (y_pred - net.y_mean.numpy()) / net.y_std.numpy()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as ps

import matplotlib as mpl

latex_lw = 404.02908
in_inch = latex_lw / 72.27
print(in_inch)

mpl.rcParams.update({
    "font.size": 11,          # base font (affects cbar label unless overridden)
    "xtick.labelsize": 10,    # affects horizontal colorbar ticks
    "ytick.labelsize": 10,    # affects vertical colorbar ticks
    # Optional extras you may want:
    "axes.titlesize": 11,
    "axes.labelsize": 10,
    "legend.fontsize": 10,
})

state_dict = torch.load("/gpfs/bwfor/work/ws/hd_gy283-my_data/models/sm_uni_samples_1e6.pth", map_location="cpu", weights_only=False)
args = state_dict['args']
model_state_dict = state_dict['model_state_dict']

net = NeuralNet(args['layer_dims'], args['x_mean'], args['x_std'], args['y_mean'], args['y_std'], batch_norm=True)
net.load_state_dict(model_state_dict)

y_true = []

net.eval()

num_batches = 300
y_true_list = []
x_in = []

for i in range(90, 100):
    #data = np.load(f"/gpfs/bwfor/work/ws/hd_gy283-my_data/data_uni/batch_{i}.npz")
    data = np.load(f"/gpfs/bwfor/work/ws/hd_gy283-my_data/data_uni_samples_1e6/batch_{i}.npz")
    output_idx = 0#data["outputIdx"][0]
    x, y = data["inputs"], data["currents"][:, output_idx]
    x_in.append(x[:, output_idx+1:])
    y_true_list.append(y)

input_tensor = torch.tensor(np.concatenate(x_in, axis=0), dtype=torch.float32)

with torch.no_grad():
    y_pred = net(input_tensor).detach().cpu()
y_true = np.concatenate(y_true_list, axis=0)[:, None]

y_pred = (y_pred - net.y_mean.numpy()) / net.y_std.numpy()
y_true = (y_true - net.y_mean.numpy()) / net.y_std.numpy()

l_bound = -1.5
u_bound = 1.5

layout = [
    ['A', 'B'],
    ['C', 'C']    
]

acc_pos = np.loadtxt('/gpfs/bwfor/work/ws/hd_gy283-my_data/data_uni/uni_configs/acceptors.txt')
don_pos = np.loadtxt('/gpfs/bwfor/work/ws/hd_gy283-my_data/data_uni/uni_configs/donors.txt')

#acc_pos = np.loadtxt('/gpfs/bwfor/work/ws/hd_gy283-my_data/data_vMB_own_pde_solver/vMB_configs/acceptors.txt')
#don_pos = np.loadtxt('/gpfs/bwfor/work/ws/hd_gy283-my_data/data_vMB_own_pde_solver/vMB_configs/donors.txt')

#acc_pos = np.loadtxt('/gpfs/bwfor/work/ws/hd_gy283-my_data/data_vMB_own_pde_solver/vMB_configs/acceptors.txt')
#don_pos = np.loadtxt('/gpfs/bwfor/work/ws/hd_gy283-my_data/data_vMB_own_pde_solver/vMB_configs/donors.txt')

train_losses = state_dict['train_losses']
val_losses = state_dict['val_losses']

fig, ax = plt.subplot_mosaic(mosaic=layout, figsize=(in_inch, in_inch))

ax['A'] = pred_vs_true(ax['A'], y_pred, y_true)
ax['B'].scatter(*acc_pos.T, s=8, alpha=.7)
ax['B'].scatter(*don_pos.T, s=8, alpha=.7)
ax['B'].set_xticks([])
ax['B'].set_yticks([])
ax['B'].spines[:].set_visible(False)

device_boundary = ps.Circle(xy=(0, 0), radius = float(np.max(np.linalg.norm(acc_pos, axis=1))) + 2.5, fill=None, lw=2.5)
ax['B'].add_patch(device_boundary)

ax['C'].spines[:].set_linewidth(1.5)
ax['C'].tick_params(direction='in')
ax['C'].set_xlabel(f'Epochs')
ax['C'].set_ylabel(f'Loss')
ax['C'].set_yscale('log')
ax['C'].plot(train_losses, label=f'Train loss', alpha=1.0)
ax['C'].plot(val_losses, label=f'Validation loss', alpha=.65)
ax['C'].legend()
ax['C'].grid(ls='--')
ax_C_2 = ax['C'].twinx()

#plt.savefig('/home/hd/hd_hd/hd_gy283/kmc_project/plots/sm_uni.pdf', bbox_inches='tight')
# Out:
# 5.590550435865505
# /tmp/ipykernel_2543126/2288861902.py:49: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   y_pred = (y_pred - net.y_mean.numpy()) / net.y_std.numpy()
