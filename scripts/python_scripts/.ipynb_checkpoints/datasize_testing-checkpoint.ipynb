# %%
import torch
import torch.nn as nn
from pathlib import Path
from argparse import Namespace
from sm import NeuralNet
from train_sm import MakeDataset, create_data_loaders, train_sm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
num_batch_list = [10, 20, 50, 100]

criterion = nn.MSELoss()

for num_batches in num_batch_list:

    args = Namespace(
        data_dir=Path(f"/home/hd/hd_hd/hd_gy283/kmc_project/data/sm_batches_1e6_vonMises_beta"),
        num_batches=num_batches,
        batch_size=128,
        normalize=False,
        hd=90,
        num_layers=8,
        num_epochs=1_000,
        lr=1e-3,
        save_name=Path(f"/gpfs/bwfor/work/ws/hd_gy283-my_data/sm_vMB_num_batches={num_batches}"),
    )

    train_loader, test_loader = create_data_loaders(args.data_dir, args.num_batches, args.batch_size, args.normalize)

    model = NeuralNet(in_features=7, out_features=1, hidden_dim=args.hd, num_layers=args.num_layers)
    model = model.to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=args.lr)

    train_sm(model=model, criterion=criterion, optimizer=optimizer, args=args, device=device, train_loader=train_loader, test_loader=test_loader)
# Out:
# raw_inputs shape: (10000, 8)
# outputs shape: (10000,)
# inputs shape: (10000, 7)
# Epoch 100/1000    Train Loss: 0.0006117004   Val Loss: 0.0005277207
# Epoch 200/1000    Train Loss: 0.0004178955   Val Loss: 0.0003378844
# Epoch 300/1000    Train Loss: 0.0002976193   Val Loss: 0.0003294485
# Epoch 400/1000    Train Loss: 0.0002674488   Val Loss: 0.0003116886
# Epoch 500/1000    Train Loss: 0.0002182436   Val Loss: 0.0003149493
# Epoch 600/1000    Train Loss: 0.0002159377   Val Loss: 0.0003042587
# Epoch 700/1000    Train Loss: 0.0001519051   Val Loss: 0.0003129444
# Epoch 800/1000    Train Loss: 0.0002219834   Val Loss: 0.0003807463
# Epoch 900/1000    Train Loss: 0.0001957915   Val Loss: 0.0003237588
# Epoch 1000/1000    Train Loss: 0.0001456988   Val Loss: 0.0003364996
# raw_inputs shape: (20000, 8)
# outputs shape: (20000,)
# inputs shape: (20000, 7)
# Epoch 100/1000    Train Loss: 0.0004845564   Val Loss: 0.0002708567
# Epoch 200/1000    Train Loss: 0.0002887415   Val Loss: 0.0001605002
# Epoch 300/1000    Train Loss: 0.0002410456   Val Loss: 0.0001569763
# Epoch 400/1000    Train Loss: 0.0002223599   Val Loss: 0.0001561883
# Epoch 500/1000    Train Loss: 0.0001919251   Val Loss: 0.0001509062
# Epoch 600/1000    Train Loss: 0.0001878270   Val Loss: 0.0001295590
# Epoch 700/1000    Train Loss: 0.0001517655   Val Loss: 0.0001474125
# Epoch 800/1000    Train Loss: 0.0001539826   Val Loss: 0.0001455073
# Epoch 900/1000    Train Loss: 0.0001411336   Val Loss: 0.0001371968
# Epoch 1000/1000    Train Loss: 0.0001473497   Val Loss: 0.0001349923
# raw_inputs shape: (50000, 8)
# outputs shape: (50000,)
# inputs shape: (50000, 7)
# Epoch 100/1000    Train Loss: 0.0003084387   Val Loss: 0.0001525730

# %%
import numpy as np
import matplotlib.pyplot as plt
from sm import NeuralNet

model = NeuralNet(in_features=7, out_features=1, hidden_dim=90, num_layers=8)
state_dict = torch.load(f=f"/gpfs/bwfor/work/ws/hd_gy283-my_data/sm_vMB_num_batches=10")
