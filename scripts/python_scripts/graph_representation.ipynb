# %%
import torch
import torch.nn
import torch_geometric
from torch_geometric.data import Data
from torch_geometric.data import HeteroData

print(f"toch_geometric.__version__ == {torch_geometric.__version__}")
# Out:
# toch_geometric.__version__ == 2.6.1
